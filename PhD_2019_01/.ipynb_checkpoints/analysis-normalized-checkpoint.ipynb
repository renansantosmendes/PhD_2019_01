# %%
import os
import numpy as np
import pandas as pd
import matplotlib. pyplot as plt
from pygmo import *
from mpl_toolkits.mplot3d import Axes3D
import methods_updated as mt
# %matplotlib inline

# %% [markdown]
# # Instância r050n12tw10k4

# %% [markdown]
# ## MOEAD-AE-5

# %%
file = 'moead-original-pareto-execution-'
instance = 'r050n12tw10k4'
algorithm_folder_5 = 'MOEAD_PCA'
algorithm_folder_5 = 'MOEAD_AE_5'
algorithm_name_5 = 'MOEAD-AE-5'
hv_moead_ae_5_r050, hv_moead_ae_5_r050_df = mt.plot_hypervolume_convergence(
    os.path.join('Results_2020/MOEAD/',algorithm_folder_5, instance),
    folder='',
    file=file,
    dimension=8,
    plot=False)
# Out:
# Results_2020/MOEAD/MOEAD_AE_5/r050n12tw10k4/moead-original-pareto-execution-0.txt
# Results_2020/MOEAD/MOEAD_AE_5/r050n12tw10k4/moead-original-pareto-execution-1.txt
# Results_2020/MOEAD/MOEAD_AE_5/r050n12tw10k4/moead-original-pareto-execution-2.txt
# Results_2020/MOEAD/MOEAD_AE_5/r050n12tw10k4/moead-original-pareto-execution-3.txt
# Results_2020/MOEAD/MOEAD_AE_5/r050n12tw10k4/moead-original-pareto-execution-4.txt
# Results_2020/MOEAD/MOEAD_AE_5/r050n12tw10k4/moead-original-pareto-execution-5.txt
# Results_2020/MOEAD/MOEAD_AE_5/r050n12tw10k4/moead-original-pareto-execution-6.txt
# Results_2020/MOEAD/MOEAD_AE_5/r050n12tw10k4/moead-original-pareto-execution-7.txt
# Results_2020/MOEAD/MOEAD_AE_5/r050n12tw10k4/moead-original-pareto-execution-8.txt
# Results_2020/MOEAD/MOEAD_AE_5/r050n12tw10k4/moead-original-pareto-execution-9.txt

# %%
plt.plot(hv_moead_ae_5_r050)
plt.show()

# %% [markdown]
# ## MOEAD-AE-4

# %%
file = 'moead-original-pareto-execution-'
instance = 'r050n12tw10k4'
algorithm_folder_4 = 'MOEAD_PCA'
algorithm_folder_4 = 'MOEAD_AE_4'
algorithm_name_4 = 'MOEAD-AE-4'
hv_moead_ae_4_r050, hv_moead_ae_4_r050_df = mt.plot_hypervolume_convergence(
    os.path.join('Results_2020/MOEAD/',algorithm_folder_4, instance),
    folder='',
    file=file,
    dimension=8,
    plot=False)
# Out:
# Results_2020/MOEAD/MOEAD_AE_4/r050n12tw10k4/moead-original-pareto-execution-0.txt
# Results_2020/MOEAD/MOEAD_AE_4/r050n12tw10k4/moead-original-pareto-execution-1.txt
# Results_2020/MOEAD/MOEAD_AE_4/r050n12tw10k4/moead-original-pareto-execution-2.txt
# Results_2020/MOEAD/MOEAD_AE_4/r050n12tw10k4/moead-original-pareto-execution-3.txt
# Results_2020/MOEAD/MOEAD_AE_4/r050n12tw10k4/moead-original-pareto-execution-4.txt
# Results_2020/MOEAD/MOEAD_AE_4/r050n12tw10k4/moead-original-pareto-execution-5.txt
# Results_2020/MOEAD/MOEAD_AE_4/r050n12tw10k4/moead-original-pareto-execution-6.txt
# Results_2020/MOEAD/MOEAD_AE_4/r050n12tw10k4/moead-original-pareto-execution-7.txt
# Results_2020/MOEAD/MOEAD_AE_4/r050n12tw10k4/moead-original-pareto-execution-8.txt
# Results_2020/MOEAD/MOEAD_AE_4/r050n12tw10k4/moead-original-pareto-execution-9.txt

# %% [markdown]
# ## MOEAD-AE-3

# %%
file = 'moead-original-pareto-execution-'
instance = 'r050n12tw10k4'
algorithm_folder_0 = 'MOEAD_PCA'
algorithm_folder_0 = 'MOEAD_AE_3'
algorithm_name_0 = 'MOEAD-AE-3'
hv_moead_ae_3_r050, hv_moead_ae_3_r050_df = mt.plot_hypervolume_convergence(
    os.path.join('Results_2020/MOEAD/',algorithm_folder_0, instance),
    folder='',
    file=file,
    dimension=8,
    plot=False)
# Out:
# Results_2020/MOEAD/MOEAD_AE_3/r050n12tw10k4/moead-original-pareto-execution-0.txt
# Results_2020/MOEAD/MOEAD_AE_3/r050n12tw10k4/moead-original-pareto-execution-1.txt
# Results_2020/MOEAD/MOEAD_AE_3/r050n12tw10k4/moead-original-pareto-execution-2.txt
# Results_2020/MOEAD/MOEAD_AE_3/r050n12tw10k4/moead-original-pareto-execution-3.txt
# Results_2020/MOEAD/MOEAD_AE_3/r050n12tw10k4/moead-original-pareto-execution-4.txt
# Results_2020/MOEAD/MOEAD_AE_3/r050n12tw10k4/moead-original-pareto-execution-5.txt
# Results_2020/MOEAD/MOEAD_AE_3/r050n12tw10k4/moead-original-pareto-execution-6.txt
# Results_2020/MOEAD/MOEAD_AE_3/r050n12tw10k4/moead-original-pareto-execution-7.txt
# Results_2020/MOEAD/MOEAD_AE_3/r050n12tw10k4/moead-original-pareto-execution-8.txt
# Results_2020/MOEAD/MOEAD_AE_3/r050n12tw10k4/moead-original-pareto-execution-9.txt

# %%
plt.plot(hv_moead_ae_4_r050)
plt.show()

# %%
hv_moead_ae_4_r050
# Out:
# 0      3.823115e+35
# 1      3.777029e+35
# 2      3.732162e+35
# 3      3.999982e+35
# 4      3.827473e+35
#            ...
# 295    5.585013e+35
# 296    5.585013e+35
# 297    5.585012e+35
# 298    5.586165e+35
# 299    5.586165e+35
# Length: 300, dtype: float64

# %% [markdown]
# ## MOEAD-AE-2

# %%
file = 'moead-original-pareto-execution-'
instance = 'r050n12tw10k4'
algorithm_folder_1 = 'MOEAD_PCA'
algorithm_folder_1 = 'MOEAD_AE_2'
algorithm_name_1 = 'MOEAD-AE-2'
hv_moead_ae_2_r050, hv_moead_ae_2_r050_df = mt.plot_hypervolume_convergence(
    os.path.join('Results_2020/MOEAD/',algorithm_folder_1, instance),
    folder='',
    file=file,
    dimension=8,
    plot=False)
# Out:
# Results_2020/MOEAD/MOEAD_AE_2/r050n12tw10k4/moead-original-pareto-execution-0.txt
# Results_2020/MOEAD/MOEAD_AE_2/r050n12tw10k4/moead-original-pareto-execution-1.txt
# Results_2020/MOEAD/MOEAD_AE_2/r050n12tw10k4/moead-original-pareto-execution-2.txt
# Results_2020/MOEAD/MOEAD_AE_2/r050n12tw10k4/moead-original-pareto-execution-3.txt
# Results_2020/MOEAD/MOEAD_AE_2/r050n12tw10k4/moead-original-pareto-execution-4.txt
# Results_2020/MOEAD/MOEAD_AE_2/r050n12tw10k4/moead-original-pareto-execution-5.txt
# Results_2020/MOEAD/MOEAD_AE_2/r050n12tw10k4/moead-original-pareto-execution-6.txt
# Results_2020/MOEAD/MOEAD_AE_2/r050n12tw10k4/moead-original-pareto-execution-7.txt
# Results_2020/MOEAD/MOEAD_AE_2/r050n12tw10k4/moead-original-pareto-execution-8.txt
# Results_2020/MOEAD/MOEAD_AE_2/r050n12tw10k4/moead-original-pareto-execution-9.txt

# %%
hv_moead_ae_2_r050
# Out:
# 0      7.077872e+34
# 1      8.560970e+34
# 2      1.150999e+35
# 3      1.559693e+35
# 4      1.825214e+35
#            ...
# 295    3.894375e+35
# 296    3.894375e+35
# 297    3.894375e+35
# 298    3.894375e+35
# 299    3.894375e+35
# Length: 300, dtype: float64

# %% [markdown]
# ## MOEAD

# %%
file = 'moead-original-pareto-execution-'
instance = 'r050n12tw10k4'
algorithm_folder_2 = 'MOEAD'
algorithm_name_2 = 'MOEAD'
hv_moead_r050, hv_moead_r050_df = mt.plot_hypervolume_convergence(
    os.path.join('Results_2020/MOEAD/',algorithm_folder_2, instance),
    folder='',
    file=file,
    dimension=8,
    plot=False)
# Out:
# Results_2020/MOEAD/MOEAD/r050n12tw10k4/moead-original-pareto-execution-0.txt
# Results_2020/MOEAD/MOEAD/r050n12tw10k4/moead-original-pareto-execution-1.txt
# Results_2020/MOEAD/MOEAD/r050n12tw10k4/moead-original-pareto-execution-2.txt
# Results_2020/MOEAD/MOEAD/r050n12tw10k4/moead-original-pareto-execution-3.txt
# Results_2020/MOEAD/MOEAD/r050n12tw10k4/moead-original-pareto-execution-4.txt
# Results_2020/MOEAD/MOEAD/r050n12tw10k4/moead-original-pareto-execution-5.txt
# Results_2020/MOEAD/MOEAD/r050n12tw10k4/moead-original-pareto-execution-6.txt
# Results_2020/MOEAD/MOEAD/r050n12tw10k4/moead-original-pareto-execution-7.txt
# Results_2020/MOEAD/MOEAD/r050n12tw10k4/moead-original-pareto-execution-8.txt
# Results_2020/MOEAD/MOEAD/r050n12tw10k4/moead-original-pareto-execution-9.txt

# %%
hv_moead_r050
# Out:
# 0      4.058521e+35
# 1      4.352101e+35
# 2      4.413091e+35
# 3      4.521380e+35
# 4      4.613992e+35
#            ...
# 295    5.424912e+35
# 296    5.424912e+35
# 297    5.424912e+35
# 298    5.433843e+35
# 299    5.433843e+35
# Length: 300, dtype: float64

# %%
plt.plot(hv_moead_r050)
plt.plot(hv_moead_ae_3_r050)

# %% [markdown]
# ## MOEAD-AE

# %%
# file = 'moead-original-pareto-execution-'
# instance = 'r050n12tw10k4'
# algorithm_folder_3 = 'MOEAD_AE'
# algorithm_name_3 = 'MOEAD-AE'
# hv_moead_ae_r050, hv_moead_ae_r050_df = mt.plot_hypervolume_convergence(
#     os.path.join('Results_2020/MOEAD/',algorithm_folder_3, instance),
#     folder='',
#     file=file,
#     dimension=8,
#     plot=False)

# %%
# hv_moead_pca_r050[0] = 1.6081469550308707e+35

plt.figure(figsize=(10,8))
plt.plot(hv_moead_ae_3_r050, label=algorithm_name_0)
plt.plot(hv_moead_ae_2_r050, label=algorithm_name_1)
plt.plot(hv_moead_r050, label=algorithm_name_2)
# plt.plot(hv_moead_ae_r050, label=algorithm_name_3)
plt.plot(hv_moead_ae_4_r050, label=algorithm_name_4)
plt.plot(hv_moead_ae_5_r050, label=algorithm_name_5)
plt.xlabel('Evaluation')
plt.legend()
plt.show()

# %%
data_to_plot = [hv_moead_ae_3_r050_df.iloc[299:].values.tolist()[0],
                hv_moead_ae_2_r050_df.iloc[299:].values.tolist()[0],
                hv_moead_r050_df.iloc[299:].values.tolist()[0],
#                 hv_moead_ae_r050_df.iloc[299:].values.tolist()[0],
                hv_moead_ae_4_r050_df.iloc[299:].values.tolist()[0],
                hv_moead_ae_5_r050_df.iloc[299:].values.tolist()[0]
               ]
plt.figure(figsize=(10, 7))
plt.boxplot(data_to_plot, labels=[algorithm_name_0,
                                  algorithm_name_1,
                                  algorithm_name_2,
#                                   algorithm_name_3,
                                  algorithm_name_4,
                                  algorithm_name_5
                                  ])
plt.show()

# %%
mt.random_test(hv_moead_r050_df.iloc[299:], hv_moead_ae_5_r050_df.iloc[299:], 10, True)
# Out:
# H0
# Limiar = 1.1853442226592312e+35
# z = 1.3262984511436342
# Mean Spread Diff 8.0446775290812915e+34

# %%
mt.random_test(hv_moead_ae_r050_df.iloc[299:], hv_moead_r050_df.iloc[299:], 10, False)
# Out:
# H0
# Limiar = 1.0880332969887105e+35
# z = -1.6736611411694757
# Mean Spread Diff -9.134238607511934e+34

# %% [markdown]
# # Instância r100n12tw10k4

# %% [markdown]
# ## MOEAD-PCA

# %%
reference_point = [350000,150000,150000,150000,150000,150000,150000,1]
file = 'moead-original-pareto-execution-'
instance = 'r100n12tw10k4'
algorithm_folder_1 = 'MOEAD_PCA'
algorithm_name_1 = 'MOEAD-PCA'
hv_moead_pca_r100, hv_moead_pca_r100_df = mt.plot_hypervolume_convergence(
    os.path.join(algorithm_folder_1, instance),
    file,
    8,
    reference_point=reference_point,
    plot=False)

# %% [markdown]
# # MOEAD

# %%
file = 'moead-original-pareto-execution-'
instance = 'r100n12tw10k4'
algorithm_folder_2 = 'MOEAD'
algorithm_name_2 = 'MOEAD'
hv_moead_r100, hv_moead_r100_df = mt.plot_hypervolume_convergence(
    os.path.join(algorithm_folder_2, instance),
    file,
    8,
    reference_point=reference_point,
    plot=False)

# %% [markdown]
# ## MOEAD-AE

# %%
file = 'moead-original-pareto-execution-'
instance = 'r100n12tw10k4'
algorithm_folder_3 = 'MOEAD_AE'
algorithm_name_3 = 'MOEAD-AE'
hv_moead_ae_r100, hv_moead_ae_r100_df = mt.plot_hypervolume_convergence(
    os.path.join(algorithm_folder_3, instance),
    file,
    8,
    reference_point=reference_point,
    plot=False)

# %%
plt.figure(figsize=(10,8))
plt.plot(hv_moead_pca_r100, label=algorithm_name_1)
plt.plot(hv_moead_r100, label=algorithm_name_2)
plt.plot(hv_moead_ae_r100, label=algorithm_name_3)
plt.xlabel('Evaluation')
plt.legend()
plt.show()

# %%
data_to_plot = [hv_moead_pca_r100_df.iloc[299:].values.tolist()[0],
                hv_moead_r100_df.iloc[299:].values.tolist()[0],
                hv_moead_ae_r100_df.iloc[299:].values.tolist()[0],
               ]
plt.figure(figsize=(10, 7))
plt.boxplot(data_to_plot, labels=[algorithm_name_1,
                                  algorithm_name_2,
                                  algorithm_name_3,
                                  ])
plt.show()

# %%
mt.random_test(hv_moead_ae_r100_df.iloc[299:], hv_moead_r100_df.iloc[299:], 10, False)
# Out:
# H0
# Limiar = 9.90972970960577e+34
# z = 0.7932745299024562
# Mean Spread Diff 4.0310248227774474e+34

# %% [markdown]
# # Instância r150n12tw10k4

# %% [markdown]
# ## MOEAD-PCA

# %%
reference_point = [480000,150000,150000,150000,150000,150000,150000,1]
file = 'moead-original-pareto-execution-'
instance = 'r150n12tw10k4'
algorithm_folder_1 = 'MOEAD_PCA'
algorithm_name_1 = 'MOEAD-PCA'
hv_moead_pca_r150, hv_moead_pca_r150_df = mt.plot_hypervolume_convergence(
    os.path.join(algorithm_folder_1, instance),
    file,
    8,
    reference_point=reference_point,
    plot=False)

# %% [markdown]
# ## MOEAD

# %%
file = 'moead-original-pareto-execution-'
instance = 'r150n12tw10k4'
algorithm_folder_2 = 'MOEAD'
algorithm_name_2 = 'MOEAD'
hv_moead_r150, hv_moead_r150_df = mt.plot_hypervolume_convergence(
    os.path.join(algorithm_folder_2, instance),
    file,
    8,
    reference_point=reference_point,
    plot=False)

# %% [markdown]
# ## MOEAD-AE

# %%
file = 'moead-original-pareto-execution-'
instance = 'r150n12tw10k4'
algorithm_folder_3 = 'MOEAD_AE'
algorithm_name_3 = 'MOEAD-AE'
hv_moead_ae_r150, hv_moead_ae_r150_df = mt.plot_hypervolume_convergence(
    os.path.join(algorithm_folder_3, instance),
    file,
    8,
    reference_point=reference_point,
    plot=False)

# %%
plt.figure(figsize=(10,8))
plt.plot(hv_moead_pca_r150, label=algorithm_name_1)
plt.plot(hv_moead_r150, label=algorithm_name_2)
plt.plot(hv_moead_ae_r150, label=algorithm_name_3)
plt.xlabel('Evaluation')
plt.legend()
plt.show()

# %%
data_to_plot = [hv_moead_pca_r150_df.iloc[299:].values.tolist()[0],
                hv_moead_r150_df.iloc[299:].values.tolist()[0],
                hv_moead_ae_r150_df.iloc[299:].values.tolist()[0]
               ]
plt.figure(figsize=(10, 7))
plt.boxplot(data_to_plot, labels=[algorithm_name_1,
                                  algorithm_name_2,
                                  algorithm_name_3
                                  ])
plt.show()

# %%
mt.random_test(hv_moead_ae_r150_df.iloc[299:], hv_moead_r150_df.iloc[299:], 10, False)
# Out:
# H0
# Limiar = 1.2060123741515322e+35
# z = -0.28506526184622316
# Mean Spread Diff -1.8132410123677187e+34

# %% [markdown]
# # Instância r200n12tw10k4

# %% [markdown]
# ## MOEAD-PCA

# %%
reference_point = [550000,150000,150000,150000,150000,150000,150000,1]
file = 'moead-original-pareto-execution-'
instance = 'r200n12tw10k4'
algorithm_folder_1 = 'MOEAD_PCA'
algorithm_name_1 = 'MOEAD-PCA'
hv_moead_pca_r200, hv_moead_pca_r200_df = mt.plot_hypervolume_convergence(
    os.path.join(algorithm_folder_1, instance),
    file,
    8,
    reference_point=reference_point,
    plot=False)

# %% [markdown]
# ## MOEAD

# %%
file = 'moead-original-pareto-execution-'
instance = 'r200n12tw10k4'
algorithm_folder_2 = 'MOEAD'
algorithm_name_2 = 'MOEAD'
hv_moead_r200, hv_moead_r200_df = mt.plot_hypervolume_convergence(
    os.path.join(algorithm_folder_2, instance),
    file,
    8,
    reference_point=reference_point,
    plot=False)

# %% [markdown]
# ## MOEAD-AE

# %%
file = 'moead-original-pareto-execution-'
instance = 'r200n12tw10k4'
algorithm_folder_3 = 'MOEAD_AE'
algorithm_name_3 = 'MOEAD-AE'
hv_moead_ae_r200, hv_moead_ae_r200_df = mt.plot_hypervolume_convergence(
    os.path.join(algorithm_folder_3, instance),
    file,
    8,
    reference_point=reference_point,
    plot=False)

# %%
plt.figure(figsize=(10,8))
plt.plot(hv_moead_pca_r200, label=algorithm_name_1)
plt.plot(hv_moead_r200, label=algorithm_name_2)
plt.plot(hv_moead_ae_r200, label=algorithm_name_3)
plt.xlabel('Evaluation')
plt.legend()
plt.show()

# %%
data_to_plot = [hv_moead_pca_r200_df.iloc[299:].values.tolist()[0],
                hv_moead_r200_df.iloc[299:].values.tolist()[0],
                hv_moead_ae_r200_df.iloc[299:].values.tolist()[0]
               ]
plt.figure(figsize=(10, 7))
plt.boxplot(data_to_plot, labels=[algorithm_name_1,
                                  algorithm_name_2,
                                  algorithm_name_3
                                  ])
plt.show()

# %%
mt.random_test(hv_moead_ae_r200_df.iloc[299:], hv_moead_r200_df.iloc[299:], 10, False)
# Out:
# H0
# Limiar = 8.456537117214563e+34
# z = -0.9041070500991306
# Mean Spread Diff -3.908279044855248e+34
